# %%
import pandas as pd

# %% [markdown]
# # How to modify the values in a dataframe?

# %%
# - We can modify the value using indexes in a dataframe.

# %%
name=['Jayanth', 'Suresh', 'Megha', 'Deepak', 'Pallavi', 'Rahul', 'Dhruv', 'Nidhi']
age=[24,26,27,21,28,25,21,26]
city=['Pune', 'Bangalore', 'Delhi', 'Hyderabad', 'Chennai','Noida', 'Gurugram', 'Dehradun']
codes=[111,112,113,114,115,116,117,118]

# %%
df=pd.DataFrame({"Name":name,
              'ID':codes,
             'Age':age,
             'City':city})

# %%
df
# Out:
#       Name   ID  Age       City
# 0  Jayanth  111   24       Pune
# 1   Suresh  112   26  Bangalore
# 2    Megha  113   27      Delhi
# 3   Deepak  114   21  Hyderabad
# 4  Pallavi  115   28    Chennai
# 5    Rahul  116   25      Noida
# 6    Dhruv  117   21   Gurugram
# 7    Nidhi  118   26   Dehradun

# %%
# The second city should be Mumbai

# %%
df.loc[1,'City']='Mumbai'

# %%
df
# Out:
#       Name   ID  Age       City
# 0  Jayanth  111   24       Pune
# 1   Suresh  112   26     Mumbai
# 2    Megha  113   27      Delhi
# 3   Deepak  114   21  Hyderabad
# 4  Pallavi  115   28    Chennai
# 5    Rahul  116   25      Noida
# 6    Dhruv  117   21   Gurugram
# 7    Nidhi  118   26   Dehradun

# %%
# ID of Rahul should be changed to 120

# %%
df.Name=='Rahul'
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# Name: Name, dtype: bool

# %%
df.loc[df.Name=='Rahul','ID']=120

# %%
df
# Out:
#       Name   ID  Age       City
# 0  Jayanth  111   24       Pune
# 1   Suresh  112   26     Mumbai
# 2    Megha  113   27      Delhi
# 3   Deepak  114   21  Hyderabad
# 4  Pallavi  115   28    Chennai
# 5    Rahul  120   25      Noida
# 6    Dhruv  117   21   Gurugram
# 7    Nidhi  118   26   Dehradun

# %%
# Change the city of Deepak to Gurugram

# %%
df.loc[df.Name=='Deepak','City']='Gurugram'

# %%
df
# Out:
#       Name   ID  Age      City
# 0  Jayanth  111   24      Pune
# 1   Suresh  112   26    Mumbai
# 2    Megha  113   27     Delhi
# 3   Deepak  114   21  Gurugram
# 4  Pallavi  115   28   Chennai
# 5    Rahul  120   25     Noida
# 6    Dhruv  117   21  Gurugram
# 7    Nidhi  118   26  Dehradun

# %%
# Importing the data from a csv or excel files.
# Importatnt functions
# Analysis
# - Conditions on a dataframe
# - groupby
# - pivot table
# - merging
# - sorting
# - aggregation
# Data Transformation
# - Capping
# - Bining
# - Encoding

# %% [markdown]
# # Importing a csv or excel file

# %%
# csv- comma separated file

# %%
# pd.read_csv(path_to_the_file)

# %%
# pd.read_excel(path_to_the_file)

# %%
path="C:\\Users\\ashis\\OneDrive\\Desktop\\Data Science\\Batches\\Practice Datasets\\Titanic.csv"

# %%
path="C:/Users/ashis/OneDrive/Desktop/Data Science/Batches/Practice Datasets/Titanic.csv"

# %%
path=r"C:\Users\ashis\OneDrive\Desktop\Data Science\Batches\Practice Datasets\Titanic.csv"

# %%
df=pd.read_csv(path)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # Functions

# %% [markdown]
# ### head()

# %%
# - It returns a data frame that contains the first 5 rows of the existing dataframe.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(120)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 115          116         0       3
# 116          117         0       3
# 117          118         0       2
# 118          119         0       1
# 119          120         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[0:50]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %% [markdown]
# ### tail()

# %%
# - It returns the last 5 rows of the dataframe

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.tail(30)
# Out:
#      PassengerId  Survived  Pclass  \
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# ...

# %% [markdown]
# ### nunique()

# %%
# - It returns the number of unique values column wise in a dataframe or in a series

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df.Pclass.nunique()
# Out:
# 3

# %%
df.Survived.nunique()
# Out:
# 2

# %% [markdown]
# ### unique()

# %%
# - It returns an array that conatins the unique values from a series.

# %%
df.Survived.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# ### value_counts()

# %%
# - It returns the count of unique values in a series

# %%
df.Survived.nunique()
# Out:
# 2

# %%
df.Survived.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
549+342
# Out:
# 891

# %%
len(df)
# Out:
# 891

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
644+168+77
# Out:
# 889

# %%
df.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df.Embarked.value_counts(dropna=False)
# Out:
# S      644
# C      168
# Q       77
# NaN      2
# Name: Embarked, dtype: int64

# %%
df.Sex.value_counts()*100/len(df)
# Out:
# male      64.758698
# female    35.241302
# Name: Sex, dtype: float64

# %%
male=577
total=891
male/total*100
# Out:
# 64.75869809203144

# %%
len(df)
# Out:
# 891

# %%
df.Embarked.value_counts(dropna=False)*100/len(df)
# Out:
# S      72.278339
# C      18.855219
# Q       8.641975
# NaN     0.224467
# Name: Embarked, dtype: float64

# %%
df.Embarked.value_counts(dropna=False,normalize=True)*100
# Out:
# S      72.278339
# C      18.855219
# Q       8.641975
# NaN     0.224467
# Name: Embarked, dtype: float64

# %% [markdown]
# # Statistical Functions

# %% [markdown]
# ### mean()

# %%
df.mean(numeric_only=True)
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %% [markdown]
# ### median()

# %%
df.median(numeric_only=True)
# Out:
# PassengerId    446.0000
# Survived         0.0000
# Pclass           3.0000
# Age             28.0000
# SibSp            0.0000
# Parch            0.0000
# Fare            14.4542
# dtype: float64

# %%
df.Fare.median()
# Out:
# 14.4542

# %% [markdown]
# ### mode()

# %%
df.mode()
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 0              1       0.0     3.0                    Abbing, Mr. Anthony
# 1              2       NaN     NaN            Abbott, Mr. Rossmore Edward
# 2              3       NaN     NaN       Abbott, Mrs. Stanton (Rosa Hunt)
# 3              4       NaN     NaN                    Abelson, Mr. Samuel
# 4              5       NaN     NaN  Abelson, Mrs. Samuel (Hannah Wizosky)
# ..           ...       ...     ...                                    ...
# 886          887       NaN     NaN                de Mulder, Mr. Theodore
# 887          888       NaN     NaN              de Pelsmaeker, Mr. Alfons
# 888          889       NaN     NaN              del Carlo, Mr. Sebastiano
# 889          890       NaN     NaN        van Billiard, Mr. Austin Blyler
# 890          891       NaN     NaN            van Melkebeke, Mr. Philemon
#
#       Sex   Age  SibSp  Parch    Ticket  Fare        Cabin Embarked
# ...

# %%
df.mode(axis=0).iloc[0]
# Out:
# PassengerId                      1
# Survived                       0.0
# Pclass                         3.0
# Name           Abbing, Mr. Anthony
# Sex                           male
# Age                           24.0
# SibSp                          0.0
# Parch                          0.0
# Ticket                        1601
# Fare                          8.05
# Cabin                      B96 B98
# Embarked                         S
# Name: 0, dtype: object

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.Age.mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
df.Age.mode().iloc[0]
# Out:
# 24.0

# %% [markdown]
# ### max(), min(), sum()

# %%
df.max(numeric_only=True)
# Out:
# PassengerId    891.0000
# Survived         1.0000
# Pclass           3.0000
# Age             80.0000
# SibSp            8.0000
# Parch            6.0000
# Fare           512.3292
# dtype: float64

# %%
df.min(numeric_only=True)
# Out:
# PassengerId    1.00
# Survived       0.00
# Pclass         1.00
# Age            0.42
# SibSp          0.00
# Parch          0.00
# Fare           0.00
# dtype: float64

# %%
df.sum(numeric_only=True)
# Out:
# PassengerId    397386.0000
# Survived          342.0000
# Pclass           2057.0000
# Age             21205.1700
# SibSp             466.0000
# Parch             340.0000
# Fare            28693.9493
# dtype: float64

# %% [markdown]
# ### var()

# %%
# - It returns the variance.

# %%
df.var(numeric_only=True)
# Out:
# PassengerId    66231.000000
# Survived           0.236772
# Pclass             0.699015
# Age              211.019125
# SibSp              1.216043
# Parch              0.649728
# Fare            2469.436846
# dtype: float64

# %%
df.Age.var()
# Out:
# 211.0191247463081

# %%
df['Age'].var()
# Out:
# 211.0191247463081

# %% [markdown]
# ### std()

# %%
# - It returns the standard deviation.

# %%
df.std(numeric_only=True)
# Out:
# PassengerId    257.353842
# Survived         0.486592
# Pclass           0.836071
# Age             14.526497
# SibSp            1.102743
# Parch            0.806057
# Fare            49.693429
# dtype: float64

# %%
df.Fare.std()
# Out:
# 49.693428597180905

# %%
df['Fare'].std()
# Out:
# 49.693428597180905

# %% [markdown]
# ### corr()

# %%
# - It returns the coorelation

# %%
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# ### quantile()

# %%
# - It returns a particular percentile value

# %%
df.quantile(0.75,numeric_only=True)
# Out:
# PassengerId    668.5
# Survived         1.0
# Pclass           3.0
# Age             38.0
# SibSp            1.0
# Parch            0.0
# Fare            31.0
# Name: 0.75, dtype: float64

# %%
df.Age.quantile(.75)
# Out:
# 38.0

# %%
df.Age.quantile([.01,.1,.25,.50,.75,.99])
# Out:
# 0.01     1.000
# 0.10    14.000
# 0.25    20.125
# 0.50    28.000
# 0.75    38.000
# 0.99    65.870
# Name: Age, dtype: float64

# %%
df.quantile([.01,.1,.25,.50,.75,.99],numeric_only=True)
# Out:
#       PassengerId  Survived  Pclass     Age  SibSp  Parch       Fare
# 0.01          9.9       0.0     1.0   1.000    0.0    0.0    0.00000
# 0.10         90.0       0.0     1.0  14.000    0.0    0.0    7.55000
# 0.25        223.5       0.0     2.0  20.125    0.0    0.0    7.91040
# 0.50        446.0       0.0     3.0  28.000    0.0    0.0   14.45420
# 0.75        668.5       1.0     3.0  38.000    1.0    0.0   31.00000
# 0.99        882.1       1.0     3.0  65.870    5.0    4.0  249.00622

# %%
df.quantile([.01,.1,.25,.50,.75,.99],numeric_only=True).T
# Out:
#              0.01   0.10      0.25      0.50   0.75       0.99
# PassengerId   9.9  90.00  223.5000  446.0000  668.5  882.10000
# Survived      0.0   0.00    0.0000    0.0000    1.0    1.00000
# Pclass        1.0   1.00    2.0000    3.0000    3.0    3.00000
# Age           1.0  14.00   20.1250   28.0000   38.0   65.87000
# SibSp         0.0   0.00    0.0000    0.0000    1.0    5.00000
# Parch         0.0   0.00    0.0000    0.0000    0.0    4.00000
# Fare          0.0   7.55    7.9104   14.4542   31.0  249.00622

# %%
import numpy as np

# %%
np.percentile(df.Age,25)
# Out:
# nan

# %%
df.Age.quantile(.25)
# Out:
# 20.125

# %%
np.percentile(df.Fare,25)
# Out:
# 7.9104

# %%
df.Fare.quantile(.25)
# Out:
# 7.9104

# %% [markdown]
# # Basic information and statistical summary of the dataframe

# %% [markdown]
# ### info()

# %%
# - It returns a series that contains some basic information of a dataframe.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### describe()

# %%
# - It returns the 5 point statistical summary of a dataframe or a series

# %%
# 5 point statistical summary
# min, q1, q2 (median), q3, max

# %%
df.describe(include='number')
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df[['Age','Fare']].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
df.describe(exclude='number')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
# Compare with mode()

# %% [markdown]
# # Handling the missing values

# %% [markdown]
# ### Checking the missing value

# %% [markdown]
# ### isna(), isnull()

# %%
# - These functions checks for the missing values and returns a boolean dataframe

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.Age.isna().sum()
# Out:
# 177

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.Age.isnull().sum()
# Out:
# 177

# %% [markdown]
# ### Dropping the missing values

# %% [markdown]
# ### dropna()

# %%
# - It drops all the rows that have atleaset 1 missing value and returns a new dataframe

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 891-183

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dropna(inplace=True)
# df=df.dropna()

# %%
df.shape
# Out:
# (183, 12)

# %%
# Importing the dataframe again

# %%
df=pd.read_csv(path)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.iloc[0:5]=np.nan

# %%
df.iloc[6,1:]=np.nan

# %%
df.iloc[0:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0          NaN       NaN     NaN
# 1          NaN       NaN     NaN
# 2          NaN       NaN     NaN
# 3          NaN       NaN     NaN
# 4          NaN       NaN     NaN
# 5          6.0       0.0     3.0
# 6          7.0       NaN     NaN
# 7          8.0       0.0     3.0
# 8          9.0       1.0     3.0
# 9         10.0       1.0     2.0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                                NaN     NaN   NaN    NaN
# 1                                                NaN     NaN   NaN    NaN
# 2                                                NaN     NaN   NaN    NaN
# 3                                                NaN     NaN   NaN    NaN
# 4                                                NaN     NaN   NaN    NaN
# 5                                   Moran, Mr. James    male   NaN    0.0
# ...

# %%
df=df.dropna(how='all')
# df.dropna(how='all',inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 5          6.0       0.0     3.0
# 6          7.0       NaN     NaN
# 7          8.0       0.0     3.0
# 8          9.0       1.0     3.0
# 9         10.0       1.0     2.0
#
#                                                 Name     Sex   Age  SibSp  \
# 5                                   Moran, Mr. James    male   NaN    0.0
# 6                                                NaN     NaN   NaN    NaN
# 7                     Palsson, Master. Gosta Leonard    male   2.0    3.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0    0.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0    1.0
#
#    Parch  Ticket     Fare Cabin Embarked
# 5    0.0  330877   8.4583   NaN        Q
# 6    NaN     NaN      NaN   NaN      NaN
# 7    1.0  349909  21.0750   NaN        S
# 8    2.0  347742  11.1333   NaN        S
# 9    0.0  237736  30.0708   NaN        C

# %%
df.shape
# Out:
# (886, 12)

# %%
# each row has 12 values.
# Keep only those rows where atleast 11 values are non-missing values

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.dropna(thresh=11,inplace=True)

# %%
df.shape
# Out:
# (727, 12)

# %% [markdown]
# ### Filling the missing values

# %%
# - We also call it missing value imputation.
# - Generally we fill the missing values with mean or median in the numeric continuous columns.
# - We fill with mode in the categorical columns.

# %%
df.dtypes
# Out:
# PassengerId    float64
# Survived       float64
# Pclass         float64
# Name            object
# Sex             object
# Age            float64
# SibSp          float64
# Parch          float64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.nunique()
# Out:
# PassengerId    727
# Survived         2
# Pclass           3
# Name           727
# Sex              2
# Age             88
# SibSp            6
# Parch            7
# Ticket         551
# Fare           223
# Cabin          145
# Embarked         3
# dtype: int64

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             19
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          526
# Embarked         2
# dtype: int64

# %% [markdown]
# ### fillna()

# %%
# - It fills the missing values with the specified value.

# %%
# df.fillna(value,inplace=True)

# %%
# Let's fill the missing values in age column with the mean value

# %%
df.Age.fillna(df.Age.mean())
# Out:
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 727, dtype: float64

# %%
df.Age.isna().sum()
# Out:
# 19

# %%
df.Age.fillna(df.Age.mean(),inplace=True)

# %%
df.Age.isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          526
# Embarked         2
# dtype: int64

# %%
# - If any column has more than 25% values as missing values then we drop that column.

# %%
df.isna().sum()*100/len(df)
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age             0.000000
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          72.352132
# Embarked        0.275103
# dtype: float64

# %%
# Since 72% values are missing in Cabin so we will drop it.

# %%
df.Embarked.dtype
# Out:
# dtype('O')

# %%
# Since Embarked is object so fill the missing values with the mode value.

# %%
df.Embarked.mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df.Embarked.mode().iloc[0]
# Out:
# 'S'

# %%
df.Embarked.fillna(df.Embarked.mode().iloc[0],inplace=True)

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          526
# Embarked         0
# dtype: int64

# %% [markdown]
# # Dropping the rows and columns

# %% [markdown]
# ### drop()

# %%
# df.drop(col_name,axis=1,inplace=True)

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 7           8.0       0.0     3.0
# 8           9.0       1.0     3.0
# 9          10.0       1.0     2.0
# 10         11.0       1.0     3.0
# 11         12.0       1.0     1.0
#
#                                                  Name     Sex   Age  SibSp  \
# 7                      Palsson, Master. Gosta Leonard    male   2.0    3.0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0    0.0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0    1.0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0    1.0
# 11                           Bonnell, Miss. Elizabeth  female  58.0    0.0
#
#     Parch   Ticket     Fare Cabin Embarked
# 7     1.0   349909  21.0750   NaN        S
# 8     2.0   347742  11.1333   NaN        S
# 9     0.0   237736  30.0708   NaN        C
# 10    1.0  PP 9549  16.7000    G6        S
# 11    0.0   113783  26.5500  C103        S

# %%
# Drop Name column

# %%
df.drop('Name',axis=1)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch   Ticket  \
# 7            8.0       0.0     3.0    male   2.0    3.0    1.0   349909
# 8            9.0       1.0     3.0  female  27.0    0.0    2.0   347742
# 9           10.0       1.0     2.0  female  14.0    1.0    0.0   237736
# 10          11.0       1.0     3.0  female   4.0    1.0    1.0  PP 9549
# 11          12.0       1.0     1.0  female  58.0    0.0    0.0   113783
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 885        886.0       0.0     3.0  female  39.0    0.0    5.0   382652
# 886        887.0       0.0     2.0    male  27.0    0.0    0.0   211536
# 887        888.0       1.0     1.0  female  19.0    0.0    0.0   112053
# 889        890.0       1.0     1.0    male  26.0    0.0    0.0   111369
# 890        891.0       0.0     3.0    male  32.0    0.0    0.0   370376
#
#         Fare Cabin Embarked
# 7    21.0750   NaN        S
# 8    11.1333   NaN        S
# ...

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 7           8.0       0.0     3.0
# 8           9.0       1.0     3.0
# 9          10.0       1.0     2.0
# 10         11.0       1.0     3.0
# 11         12.0       1.0     1.0
#
#                                                  Name     Sex   Age  SibSp  \
# 7                      Palsson, Master. Gosta Leonard    male   2.0    3.0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0    0.0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0    1.0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0    1.0
# 11                           Bonnell, Miss. Elizabeth  female  58.0    0.0
#
#     Parch   Ticket     Fare Cabin Embarked
# 7     1.0   349909  21.0750   NaN        S
# 8     2.0   347742  11.1333   NaN        S
# 9     0.0   237736  30.0708   NaN        C
# 10    1.0  PP 9549  16.7000    G6        S
# 11    0.0   113783  26.5500  C103        S

# %%
df.drop('Name',axis=1,inplace=True)

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch   Ticket  \
# 7           8.0       0.0     3.0    male   2.0    3.0    1.0   349909
# 8           9.0       1.0     3.0  female  27.0    0.0    2.0   347742
# 9          10.0       1.0     2.0  female  14.0    1.0    0.0   237736
# 10         11.0       1.0     3.0  female   4.0    1.0    1.0  PP 9549
# 11         12.0       1.0     1.0  female  58.0    0.0    0.0   113783
#
#        Fare Cabin Embarked
# 7   21.0750   NaN        S
# 8   11.1333   NaN        S
# 9   30.0708   NaN        C
# 10  16.7000    G6        S
# 11  26.5500  C103        S

# %%
# Drop PassengerID, Ticket and Cabin columns

# %%
df.drop(['Ticket','Cabin','PassengerId'],axis=1)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 7         0.0     3.0    male   2.0    3.0    1.0  21.0750        S
# 8         1.0     3.0  female  27.0    0.0    2.0  11.1333        S
# 9         1.0     2.0  female  14.0    1.0    0.0  30.0708        C
# 10        1.0     3.0  female   4.0    1.0    1.0  16.7000        S
# 11        1.0     1.0  female  58.0    0.0    0.0  26.5500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 885       0.0     3.0  female  39.0    0.0    5.0  29.1250        Q
# 886       0.0     2.0    male  27.0    0.0    0.0  13.0000        S
# 887       1.0     1.0  female  19.0    0.0    0.0  30.0000        S
# 889       1.0     1.0    male  26.0    0.0    0.0  30.0000        C
# 890       0.0     3.0    male  32.0    0.0    0.0   7.7500        Q
#
# [727 rows x 8 columns]

# %%
df.drop(columns=['Ticket','Cabin','PassengerId'])
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 7         0.0     3.0    male   2.0    3.0    1.0  21.0750        S
# 8         1.0     3.0  female  27.0    0.0    2.0  11.1333        S
# 9         1.0     2.0  female  14.0    1.0    0.0  30.0708        C
# 10        1.0     3.0  female   4.0    1.0    1.0  16.7000        S
# 11        1.0     1.0  female  58.0    0.0    0.0  26.5500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 885       0.0     3.0  female  39.0    0.0    5.0  29.1250        Q
# 886       0.0     2.0    male  27.0    0.0    0.0  13.0000        S
# 887       1.0     1.0  female  19.0    0.0    0.0  30.0000        S
# 889       1.0     1.0    male  26.0    0.0    0.0  30.0000        C
# 890       0.0     3.0    male  32.0    0.0    0.0   7.7500        Q
#
# [727 rows x 8 columns]

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch   Ticket  \
# 7           8.0       0.0     3.0    male   2.0    3.0    1.0   349909
# 8           9.0       1.0     3.0  female  27.0    0.0    2.0   347742
# 9          10.0       1.0     2.0  female  14.0    1.0    0.0   237736
# 10         11.0       1.0     3.0  female   4.0    1.0    1.0  PP 9549
# 11         12.0       1.0     1.0  female  58.0    0.0    0.0   113783
#
#        Fare Cabin Embarked
# 7   21.0750   NaN        S
# 8   11.1333   NaN        S
# 9   30.0708   NaN        C
# 10  16.7000    G6        S
# 11  26.5500  C103        S

# %%
df.drop(columns=['Ticket','Cabin','PassengerId'],inplace=True)

# %%
df.head()
# Out:
#     Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 7        0.0     3.0    male   2.0    3.0    1.0  21.0750        S
# 8        1.0     3.0  female  27.0    0.0    2.0  11.1333        S
# 9        1.0     2.0  female  14.0    1.0    0.0  30.0708        C
# 10       1.0     3.0  female   4.0    1.0    1.0  16.7000        S
# 11       1.0     1.0  female  58.0    0.0    0.0  26.5500        S

# %% [markdown]
# ### Dropping the rows

# %%
df.drop([8,15,18],inplace=True)

# %%
df.head(10)
# Out:
#     Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 7        0.0     3.0    male   2.0    3.0    1.0  21.0750        S
# 9        1.0     2.0  female  14.0    1.0    0.0  30.0708        C
# 10       1.0     3.0  female   4.0    1.0    1.0  16.7000        S
# 11       1.0     1.0  female  58.0    0.0    0.0  26.5500        S
# 12       0.0     3.0    male  20.0    0.0    0.0   8.0500        S
# 13       0.0     3.0    male  39.0    1.0    5.0  31.2750        S
# 14       0.0     3.0  female  14.0    0.0    0.0   7.8542        S
# 16       0.0     3.0    male   2.0    4.0    1.0  29.1250        Q
# 20       0.0     2.0    male  35.0    0.0    0.0  26.0000        S
# 21       1.0     2.0    male  34.0    0.0    0.0  13.0000        S

# %% [markdown]
# # Renaming the columns

# %%
df.head()
# Out:
#     Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 7        0.0     3.0    male   2.0    3.0    1.0  21.0750        S
# 9        1.0     2.0  female  14.0    1.0    0.0  30.0708        C
# 10       1.0     3.0  female   4.0    1.0    1.0  16.7000        S
# 11       1.0     1.0  female  58.0    0.0    0.0  26.5500        S
# 12       0.0     3.0    male  20.0    0.0    0.0   8.0500        S

# %%
# sex- Gender, SibSp- Siblings, Parch-Parents

# %%
df.rename({'Sex':'Gender','Parch':'Parents','SibSp':'Siblings'},axis=1,inplace=True)

# %%
df.head()
# Out:
#     Survived  Pclass  Gender   Age  Siblings  Parents     Fare Embarked
# 7        0.0     3.0    male   2.0       3.0      1.0  21.0750        S
# 9        1.0     2.0  female  14.0       1.0      0.0  30.0708        C
# 10       1.0     3.0  female   4.0       1.0      1.0  16.7000        S
# 11       1.0     1.0  female  58.0       0.0      0.0  26.5500        S
# 12       0.0     3.0    male  20.0       0.0      0.0   8.0500        S

# %% [markdown]
# # Data Filteration

# %%
# - We can filter the data using the conditions.
# - In Pandas we use bitwise and (&), bitwise or (|) and bitwise not (~) instead of logical operators.

# %%
# Get the data of male passengers

# %%
df[df.Gender=='male']
# Out:
#      Survived  Pclass Gender   Age  Siblings  Parents    Fare Embarked
# 7         0.0     3.0   male   2.0       3.0      1.0  21.075        S
# 12        0.0     3.0   male  20.0       0.0      0.0   8.050        S
# 13        0.0     3.0   male  39.0       1.0      5.0  31.275        S
# 16        0.0     3.0   male   2.0       4.0      1.0  29.125        Q
# 20        0.0     2.0   male  35.0       0.0      0.0  26.000        S
# ..        ...     ...    ...   ...       ...      ...     ...      ...
# 883       0.0     2.0   male  28.0       0.0      0.0  10.500        S
# 884       0.0     3.0   male  25.0       0.0      0.0   7.050        S
# 886       0.0     2.0   male  27.0       0.0      0.0  13.000        S
# 889       1.0     1.0   male  26.0       0.0      0.0  30.000        C
# 890       0.0     3.0   male  32.0       0.0      0.0   7.750        Q
#
# [462 rows x 8 columns]

# %%
# Get the age of male passengers

# %%
df[df.Gender=='male'][['Age','Gender']]
# Out:
#       Age Gender
# 7     2.0   male
# 12   20.0   male
# 13   39.0   male
# 16    2.0   male
# 20   35.0   male
# ..    ...    ...
# 883  28.0   male
# 884  25.0   male
# 886  27.0   male
# 889  26.0   male
# 890  32.0   male
#
# [462 rows x 2 columns]

# %%
# Get the average age of male passengers

# %%
df[df.Gender=='male']['Age'].mean()
# Out:
# 30.658052681781495

# %%
# Average fare of male passengers travelling in Pclass 1

# %%
df[(df.Gender=='male')&(df.Pclass==1)]['Fare'].mean()
# Out:
# 69.10439279279278

# %%
# Average Fare of Male and Female passengers separately who are more than 60 years of age

# %%
df[(df.Age>60)&(df.Gender=='male')]['Fare'].mean()
# Out:
# 39.08531052631579

# %%
df[(df.Age>60)&(df.Gender=='female')]['Fare'].mean()
# Out:
# 55.8486

# %%
# What is the minimum fare in Pclass 1 for the male passengers who are more than 50 years of age?

# %%
df[(df.Pclass==1)&(df.Gender=='male')&(df.Age>50)]['Fare'].min()
# Out:
# 26.0

# %%
# Average Fare for the passengers who are not male and not travelling in Pclass 1

# %%
df[~((df.Gender=='male')|(df.Pclass==1))]['Fare'].mean()
# Out:
# 18.536303448275863

# %%
df[(~(df.Gender=='male'))&(~(df.Pclass==1))]['Fare'].mean()
# Out:
# 18.536303448275863

# %%
# Make the Fare 0 for the passengers who are less than 10 years of age

# %%
df[df.Age<10]['Fare']=0 # will not modify the values

# %%
df[df.Age<10]
# Out:
#      Survived  Pclass  Gender   Age  Siblings  Parents     Fare Embarked
# 7         0.0     3.0    male  2.00       3.0      1.0  21.0750        S
# 10        1.0     3.0  female  4.00       1.0      1.0  16.7000        S
# 16        0.0     3.0    male  2.00       4.0      1.0  29.1250        Q
# 24        0.0     3.0  female  8.00       3.0      1.0  21.0750        S
# 43        1.0     2.0  female  3.00       1.0      2.0  41.5792        C
# ..        ...     ...     ...   ...       ...      ...      ...      ...
# 827       1.0     2.0    male  1.00       0.0      2.0  37.0042        C
# 831       1.0     2.0    male  0.83       1.0      1.0  18.7500        S
# 850       0.0     3.0    male  4.00       4.0      2.0  31.2750        S
# 852       0.0     3.0  female  9.00       1.0      1.0  15.2458        C
# 869       1.0     3.0    male  4.00       1.0      1.0  11.1333        S
#
# [62 rows x 8 columns]

# %%
df.loc[df.Age<10,'Fare']=0

# %%
df[df.Age<10]
# Out:
#      Survived  Pclass  Gender   Age  Siblings  Parents  Fare Embarked
# 7         0.0     3.0    male  2.00       3.0      1.0   0.0        S
# 10        1.0     3.0  female  4.00       1.0      1.0   0.0        S
# 16        0.0     3.0    male  2.00       4.0      1.0   0.0        Q
# 24        0.0     3.0  female  8.00       3.0      1.0   0.0        S
# 43        1.0     2.0  female  3.00       1.0      2.0   0.0        C
# ..        ...     ...     ...   ...       ...      ...   ...      ...
# 827       1.0     2.0    male  1.00       0.0      2.0   0.0        C
# 831       1.0     2.0    male  0.83       1.0      1.0   0.0        S
# 850       0.0     3.0    male  4.00       4.0      2.0   0.0        S
# 852       0.0     3.0  female  9.00       1.0      1.0   0.0        C
# 869       1.0     3.0    male  4.00       1.0      1.0   0.0        S
#
# [62 rows x 8 columns]

# %% [markdown]
# # groupby()

# %%
# - It is used for bivariate or multivariate analysis

# %%
# df.groupby('col').col.function()

# %%
# Average Age of Male Female Passengers

# %%
df[df.Gender=='male']['Age'].mean()
# Out:
# 30.658052681781495

# %%
df[df.Gender=='female']['Age'].mean()
# Out:
# 27.792287650407555

# %%
# Gender
# Age
# Operation- mean (Age)

# %%
df.groupby('Gender').Age.mean()
# Out:
# Gender
# female    27.792288
# male      30.658053
# Name: Age, dtype: float64

# %%
# df.groupby('Age').Gender.mean()

# %%
# Avaerage Fare of Male and Female passengers in Pclass 1

# %%
# Gender
# Fare
# Pclass
# Operation- mean (Fare)

# %%
df.groupby(['Gender','Pclass']).Fare.mean()
# Out:
# Gender  Pclass
# female  1.0       105.613495
#         2.0        18.620270
#         3.0        11.597877
# male    1.0        67.001615
#         2.0        18.630766
#         3.0         9.889680
# Name: Fare, dtype: float64

# %%
df.groupby(['Pclass','Gender']).Fare.mean()
# Out:
# Pclass  Gender
# 1.0     female    105.613495
#         male       67.001615
# 2.0     female     18.620270
#         male       18.630766
# 3.0     female     11.597877
#         male        9.889680
# Name: Fare, dtype: float64

# %%
pd.DataFrame(df.groupby(['Pclass','Gender']).Fare.mean())
# Out:
#                      Fare
# Pclass Gender
# 1.0    female  105.613495
#        male     67.001615
# 2.0    female   18.620270
#        male     18.630766
# 3.0    female   11.597877
#        male      9.889680

# %%
df.groupby(['Pclass','Gender']).Fare.mean()[1.0]['female']
# Out:
# 105.61349545454546

# %%
df.groupby(['Pclass','Gender']).Fare.mean()
# Out:
# Pclass  Gender
# 1.0     female    105.613495
#         male       67.001615
# 2.0     female     18.620270
#         male       18.630766
# 3.0     female     11.597877
#         male        9.889680
# Name: Fare, dtype: float64

# %%
df[df.Gender=='male'].groupby('Pclass').Fare.mean()
# Out:
# Pclass
# 1.0    67.001615
# 2.0    18.630766
# 3.0     9.889680
# Name: Fare, dtype: float64

# %%
# How many male and female are travelling in each pclass?

# %%
# Plclass
# Gender
# Operation- value_counts() (Pclass/Gender)

# %%
df.groupby('Pclass').Gender.value_counts()
# Out:
# Pclass  Gender
# 1.0     male      111
#         female     88
# 2.0     male       99
#         female     74
# 3.0     male      252
#         female    100
# Name: Gender, dtype: int64

# %%
df.groupby('Gender').Pclass.value_counts()
# Out:
# Gender  Pclass
# female  3.0       100
#         1.0        88
#         2.0        74
# male    3.0       252
#         1.0       111
#         2.0        99
# Name: Pclass, dtype: int64

# %% [markdown]
# # Pivot Table

# %%
# - It is used to summarise the data.

# %% [markdown]
# ### pd.pivot_table()

# %%
# - It returns a dataframe

# %%
# pd.pivot_table(df, index=,columns=,values=,aggfunc=)

# %%
# index= list of columns
# columns=list of columns
# values=column
# aggfunc=operation

# %%
path=r"C:\Users\ashis\OneDrive\Desktop\Data Science\Batches\Practice Datasets\sales.xlsx"

# %%
sls=pd.read_excel(path)

# %%
sls.head()
# Out:
#    Year    Month           Type Salesperson Region    Sales  Units  Order #
# 0  2013  January      Ice Cream      Bishop   West   2395.5   1597        1
# 1  2013  January      Ice Cream      Bishop   West  11761.5   7841        2
# 2  2013  January  Frozen Yogurt      Bishop   West   8943.0   5962        3
# 3  2013  January      Ice Cream      Bishop   West   2395.5   1597        4
# 4  2013  January      Ice Cream      Bishop   West  11761.5   7841        5

# %%
sls.shape
# Out:
# (60, 8)

# %%
# Region wise total Sales

# %%
# Region
# Sales
# Operation- sum (Sales)

# %%
sls.groupby('Region').Sales.sum()
# Out:
# Region
# Central    280674.0
# North       72741.0
# South       21321.0
# West       138600.0
# Name: Sales, dtype: float64

# %%
# Region
# Sales
# Operation- Sum (aggfunc) on Sales (values)

# %%
pd.pivot_table(sls,index='Region',values='Sales',aggfunc='sum')
# Out:
#             Sales
# Region
# Central  280674.0
# North     72741.0
# South     21321.0
# West     138600.0

# %%
pd.pivot_table(sls,columns='Region',values='Sales',aggfunc='sum')
# Out:
# Region   Central    North    South      West
# Sales   280674.0  72741.0  21321.0  138600.0

# %%
# Region wise total Sales of each product

# %%
# Region
# Type
# Sales
# Operation- sum (aggfunc) on Sales (values)

# %%
pd.pivot_table(sls,values='Sales',aggfunc='sum',index='Region',columns='Type',fill_value=0)
# Out:
# Type     Frozen Yogurt  Ice Cream  Popsicles  Tasty Treats
# Region
# Central         175158          0          0        105516
# North                0      72741          0             0
# South                0          0      21321             0
# West             53658      84942          0             0

# %%
pd.pivot_table(sls,values='Sales',aggfunc='sum',columns='Region',index='Type',fill_value=0)
# Out:
# Region         Central  North  South   West
# Type
# Frozen Yogurt   175158      0      0  53658
# Ice Cream            0  72741      0  84942
# Popsicles            0      0  21321      0
# Tasty Treats    105516      0      0      0

# %%
pd.pivot_table(sls,values='Sales',aggfunc='sum',index=['Region','Type'])
# Out:
#                           Sales
# Region  Type
# Central Frozen Yogurt  175158.0
#         Tasty Treats   105516.0
# North   Ice Cream       72741.0
# South   Popsicles       21321.0
# West    Frozen Yogurt   53658.0
#         Ice Cream       84942.0

# %%
pd.pivot_table(sls,values='Sales',aggfunc='sum',columns=['Region','Type'])
# Out:
# Region       Central                  North     South          West
# Type   Frozen Yogurt Tasty Treats Ice Cream Popsicles Frozen Yogurt Ice Cream
# Sales       175158.0     105516.0   72741.0   21321.0       53658.0   84942.0

# %%
# Region wise total sales of each product made by each Salesperson

# %%
# Region
# Sales
# Salesperson
# Type

# %%
pd.pivot_table(sls,index=['Region','Type'],columns='Salesperson',values='Sales',aggfunc='sum',fill_value=0)
# Out:
# Salesperson            Bishop    Lee  Parker  Pullen  Watson
# Region  Type
# Central Frozen Yogurt       0  87579       0       0   87579
#         Tasty Treats        0  52758       0       0   52758
# North   Ice Cream           0      0   72741       0       0
# South   Popsicles           0      0       0   21321       0
# West    Frozen Yogurt   53658      0       0       0       0
#         Ice Cream       84942      0       0       0       0

# %%
pd.pivot_table(sls,columns=['Region','Type'],index='Salesperson',values='Sales',aggfunc='sum',fill_value=0)
# Out:
# Region            Central                  North     South          West  \
# Type        Frozen Yogurt Tasty Treats Ice Cream Popsicles Frozen Yogurt
# Salesperson
# Bishop                  0            0         0         0         53658
# Lee                 87579        52758         0         0             0
# Parker                  0            0     72741         0             0
# Pullen                  0            0         0     21321             0
# Watson              87579        52758         0         0             0
#
# Region
# Type        Ice Cream
# Salesperson
# Bishop          84942
# Lee                 0
# Parker              0
# Pullen              0
# Watson              0

# %%
# Region wise total sales and total number of units sols of each product made by each Salesperson

# %%
# Region
# Sales
# Units
# Salesperson
# Type

# %%
pd.pivot_table(sls,columns=['Region','Type'],index='Salesperson',values=['Sales','Units'],aggfunc='sum',fill_value=0)
# Out:
#                     Sales                                                 \
# Region            Central                  North     South          West
# Type        Frozen Yogurt Tasty Treats Ice Cream Popsicles Frozen Yogurt
# Salesperson
# Bishop                  0            0         0         0         53658
# Lee                 87579        52758         0         0             0
# Parker                  0            0     72741         0             0
# Pullen                  0            0         0     21321             0
# Watson              87579        52758         0         0             0
#
#                               Units                                   \
# Region                      Central                  North     South
# Type        Ice Cream Frozen Yogurt Tasty Treats Ice Cream Popsicles
# Salesperson
# Bishop          84942             0            0         0         0
# Lee                 0         58386        35172         0         0
# ...

# %%
# Region wise total and average sales of each product made by each Salesperson

# %%
pd.pivot_table(sls,columns=['Region','Type'],index='Salesperson',values=['Sales'],aggfunc=['sum','mean'],fill_value=0)
# Out:
#                       sum                                                 \
#                     Sales
# Region            Central                  North     South          West
# Type        Frozen Yogurt Tasty Treats Ice Cream Popsicles Frozen Yogurt
# Salesperson
# Bishop                  0            0         0         0         53658
# Lee                 87579        52758         0         0             0
# Parker                  0            0     72741         0             0
# Pullen                  0            0         0     21321             0
# Watson              87579        52758         0         0             0
#
#                                mean                                   \
#                               Sales
# Region                      Central                  North     South
# Type        Ice Cream Frozen Yogurt Tasty Treats Ice Cream Popsicles
# Salesperson
# Bishop          84942           0.0            0      0.00       0.0
# ...

# %%
pd.pivot_table(sls,columns=['Region','Type'],index='Salesperson',values=['Sales','Units'],aggfunc=['sum','mean'],fill_value=0).T
# Out:
# Salesperson                        Bishop      Lee    Parker   Pullen   Watson
#            Region  Type
# sum  Sales Central Frozen Yogurt      0.0  87579.0      0.00      0.0  87579.0
#                    Tasty Treats       0.0  52758.0      0.00      0.0  52758.0
#            North   Ice Cream          0.0      0.0  72741.00      0.0      0.0
#            South   Popsicles          0.0      0.0      0.00  21321.0      0.0
#            West    Frozen Yogurt  53658.0      0.0      0.00      0.0      0.0
#                    Ice Cream      84942.0      0.0      0.00      0.0      0.0
#      Units Central Frozen Yogurt      0.0  58386.0      0.00      0.0  58386.0
#                    Tasty Treats       0.0  35172.0      0.00      0.0  35172.0
#            North   Ice Cream          0.0      0.0  63012.00      0.0      0.0
#            South   Popsicles          0.0      0.0      0.00  14214.0      0.0
#            West    Frozen Yogurt  35772.0      0.0      0.00      0.0      0.0
# ...

# %%
pd.pivot_table(sls,columns=['Region'],index='Salesperson',values=['Sales'],aggfunc='sum',fill_value=0)
# Out:
#               Sales
# Region      Central  North  South    West
# Salesperson
# Bishop            0      0      0  138600
# Lee          140337      0      0       0
# Parker            0  72741      0       0
# Pullen            0      0  21321       0
# Watson       140337      0      0       0
